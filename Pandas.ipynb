# %%
import pandas as pd

# %% [markdown]
# # Create dataframe using dictionary

# %%
a={
    "Name":["Sam","Imran","Simran","Raj","Loki","Kunal","Parth","Hardik","Payal","Komal"],
    "Dept":["HR","Sales","BackOffice","Front-end","Back-end","DB","CRM","SRS","Scrum","PO"],
    "Salary":[30000,20000,25000,40000,50000,30000,70000,45000,37000,27000]
}

# %%
a
# Out:
# {'Name': ['Imran', 'Sagar', 'Komal', 'Prashant', 'Payal'],
#  'Dept': ['HR', 'Sales', 'BackOffice', 'DB', 'Tele'],
#  'Salary': [30000, 35000, 20000, 50000, 40000]}

# %%
b=pd.DataFrame(a)
b
# Out:
#      Name        Dept  Salary
# 0     Sam          HR   30000
# 1   Imran       Sales   20000
# 2  Simran  BackOffice   25000
# 3     Raj   Front-end   40000
# 4    Loki    Back-end   50000
# 5   Kunal          DB   30000
# 6   Parth         CRM   70000
# 7  Hardik         SRS   45000
# 8   Payal       Scrum   37000
# 9   Komal          PO   27000

# %% [markdown]
# # How to check top 5 and bottom 5 data in a dataframe?

# %%
b.head()#gives top 5 data from frame by default
# Out:
#      Name        Dept  Salary
# 0     Sam          HR   30000
# 1   Imran       Sales   20000
# 2  Simran  BackOffice   25000
# 3     Raj   Front-end   40000
# 4    Loki    Back-end   50000

# %%
b.head(7)#Gives no of values as passed from top
# Out:
#      Name        Dept  Salary
# 0     Sam          HR   30000
# 1   Imran       Sales   20000
# 2  Simran  BackOffice   25000
# 3     Raj   Front-end   40000
# 4    Loki    Back-end   50000
# 5   Kunal          DB   30000
# 6   Parth         CRM   70000

# %%
b.tail()#gives bottom 5 data from dataframe
# Out:
#      Name   Dept  Salary
# 5   Kunal     DB   30000
# 6   Parth    CRM   70000
# 7  Hardik    SRS   45000
# 8   Payal  Scrum   37000
# 9   Komal     PO   27000

# %%
b.tail(2)#gives no of data as passed from the bottom
# Out:
#     Name   Dept  Salary
# 8  Payal  Scrum   37000
# 9  Komal     PO   27000

# %%
# To get random data from dataframe

# %%
b.sample()#gives single random data
# Out:
#     Name Dept  Salary
# 9  Komal   PO   27000

# %%
b.sample(3)#gives random data for no which is passed
# Out:
#      Name Dept  Salary
# 5   Kunal   DB   30000
# 7  Hardik  SRS   45000
# 0     Sam   HR   30000

# %% [markdown]
# # How to export/save data of dataframe to Excel?

# %%
# b.to_csv("EmploymentInfo.csv")

# %%
b.to_csv("EmploymentInfo.csv",index=False)#To exclude index values

# %% [markdown]
# # Describe()-It is used for viewing statistical data of a dataframe.

# %%
a={
    "Name":["Imran","Sagar","Komal","Prashant","Payal"],
    "Dept":["HR","Sales","BackOffice","DB","Tele"],
    "Salary":[30000,35000,20000,50000,40000]
}

# %%
df=pd.DataFrame(a)
df
# Out:
#        Name        Dept  Salary
# 0     Imran          HR   30000
# 1     Sagar       Sales   35000
# 2     Komal  BackOffice   20000
# 3  Prashant          DB   50000
# 4     Payal        Tele   40000

# %%
df.describe()
# Out:
#              Salary
# count      5.000000
# mean   35000.000000
# std    11180.339887
# min    20000.000000
# 25%    30000.000000
# 50%    35000.000000
# 75%    40000.000000
# max    50000.000000

# %%
df["Working_hours"]=[8,7,7,5,9]
df#To add another coloumn and its values
# Out:
#        Name        Dept  Salary  Working_hours
# 0     Imran          HR   30000              8
# 1     Sagar       Sales   35000              7
# 2     Komal  BackOffice   20000              7
# 3  Prashant          DB   50000              5
# 4     Payal        Tele   40000              9

# %%
#To get specific coloumn
df["Name"]
# Out:
# 0       Imran
# 1       Sagar
# 2       Komal
# 3    Prashant
# 4       Payal
# Name: Name, dtype: object

# %%
df["Dept"]
# Out:
# 0            HR
# 1         Sales
# 2    BackOffice
# 3            DB
# 4          Tele
# Name: Dept, dtype: object

# %%
#To update or change certain value
df["Salary"][3]=37000
df
# Out:
# C:\Users\IMRAN_PC\AppData\Local\Temp\ipykernel_6992\1457334158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Salary"][3]=37000
#        Name        Dept  Salary  Working_hours
# 0     Imran          HR   30000              8
# 1     Sagar       Sales   35000              7
# 2     Komal  BackOffice   20000              7
# 3  Prashant          DB   37000              5
# 4     Payal        Tele   40000              9

# %%
df["Name"][3]="Ruby"
df["Dept"][4]="Sales"
df["Working_hours"][4]=5
df
# Out:
# C:\Users\IMRAN_PC\AppData\Local\Temp\ipykernel_6992\40062328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"][3]="Ruby"
# C:\Users\IMRAN_PC\AppData\Local\Temp\ipykernel_6992\40062328.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dept"][4]="Sales"
# C:\Users\IMRAN_PC\AppData\Local\Temp\ipykernel_6992\40062328.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Working_hours"][4]=5
# ...

# %%
df1=df.copy()#To make a copy of df
df1
# Out:
#     Name        Dept  Salary  Working_hours
# 0  Imran          HR   30000              8
# 1  Sagar       Sales   35000              7
# 2  Komal  BackOffice   20000              7
# 3   Ruby          DB   37000              5
# 4  Payal       Sales   40000              5

# %% [markdown]
# # Pandas Structure
# #1.Series
# #2.DataFrame

# %% [markdown]
# # Series is a 1D array with indexes which stores data in a single coloumn or row

# %%
import numpy as np

# %%
a=pd.Series(np.random.rand(5))
a
# Out:
# 0    0.534537
# 1    0.617291
# 2    0.581464
# 3    0.222193
# 4    0.775356
# dtype: float64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # DataFrame is a tabular spreadsheet which has 1D or multi dimensional data

# %%
df=pd.DataFrame(np.random.rand(10,10))#(Rows,coloumns)
df
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.302702  0.431236  0.504984  0.536641  0.863010  0.418076  0.942255
# 1  0.351010  0.643151  0.765040  0.748425  0.681124  0.485419  0.566677
# 2  0.778214  0.992226  0.588463  0.947815  0.388662  0.597219  0.087060
# 3  0.973851  0.107084  0.126589  0.534288  0.304835  0.489964  0.363310
# 4  0.714812  0.866559  0.652321  0.258864  0.252110  0.238966  0.303474
# 5  0.223375  0.991690  0.577550  0.176397  0.358699  0.651669  0.436828
# 6  0.370057  0.053240  0.495085  0.869109  0.567061  0.480139  0.760933
# 7  0.186813  0.258570  0.752793  0.537678  0.624692  0.846056  0.384039
# 8  0.079058  0.993212  0.758575  0.491986  0.830479  0.145216  0.518155
# 9  0.178527  0.231378  0.197532  0.398684  0.120930  0.868522  0.046290
#
#           7         8         9
# 0  0.173519  0.926538  0.160742
# 1  0.584534  0.953977  0.600311
# 2  0.869368  0.177589  0.839606
# 3  0.213610  0.199620  0.130631
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns=list("ABCDEFGHIJ")#To rename columns
df
# Out:
#           A         B         C         D         E         F         G  \
# 0  0.302702  0.431236  0.504984  0.536641  0.863010  0.418076  0.942255
# 1  0.351010  0.643151  0.765040  0.748425  0.681124  0.485419  0.566677
# 2  0.778214  0.992226  0.588463  0.947815  0.388662  0.597219  0.087060
# 3  0.973851  0.107084  0.126589  0.534288  0.304835  0.489964  0.363310
# 4  0.714812  0.866559  0.652321  0.258864  0.252110  0.238966  0.303474
# 5  0.223375  0.991690  0.577550  0.176397  0.358699  0.651669  0.436828
# 7  0.186813  0.258570  0.752793  0.537678  0.624692  0.846056  0.384039
# 8  0.079058  0.993212  0.758575  0.491986  0.830479  0.145216  0.518155
# 9  0.178527  0.231378  0.197532  0.398684  0.120930  0.868522  0.046290
#
#           H         I         J
# 5  0.743466  0.435159  0.321105
# 6  0.254489  0.692024  0.709271
# 7  0.053788  0.881443  0.471816
# 8  0.739588  0.263780  0.476368
# 9  0.525323  0.222988  0.570060

# %%
df1["A"][2]=0.5555
df1
# Out:
#           A         B         C         D         E         F         G  \
# 0  0.302702  0.431236  0.504984  0.536641  0.863010  0.418076  0.942255
# 1  0.351010  0.643151  0.765040  0.748425  0.681124  0.485419  0.566677
# 2  0.555500  0.992226  0.588463  0.947815  0.388662  0.597219  0.087060
# 3  0.973851  0.107084  0.126589  0.534288  0.304835  0.489964  0.363310
# 4  0.714812  0.866559  0.652321  0.258864  0.252110  0.238966  0.303474
# 5  0.223375  0.991690  0.577550  0.176397  0.358699  0.651669  0.436828
# 6  0.370057  0.053240  0.495085  0.869109  0.567061  0.480139  0.760933
# 7  0.186813  0.258570  0.752793  0.537678  0.624692  0.846056  0.384039
# 8  0.079058  0.993212  0.758575  0.491986  0.830479  0.145216  0.518155
# 9  0.178527  0.231378  0.197532  0.398684  0.120930  0.868522  0.046290
#
#           H         I         J
# 0  0.173519  0.926538  0.160742
# 1  0.584534  0.953977  0.600311
# 2  0.869368  0.177589  0.839606
# 3  0.213610  0.199620  0.130631
# ...

# %%
df1.dtypes#To check data type
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# E    float64
# F    float64
# G    float64
# H    float64
# I    float64
# J    float64
# dtype: object

# %%
df.index#To know index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
a={
    "Name":["Imran","Sagar","Komal","Prashant","Payal"],
    "Dept":["HR","Sales","BackOffice","DB","Tele"],
    "Salary":[30000,35000,20000,50000,40000]
}
a
# Out:
# {'Name': ['Imran', 'Sagar', 'Komal', 'Prashant', 'Payal'],
#  'Dept': ['HR', 'Sales', 'BackOffice', 'DB', 'Tele'],
#  'Salary': [30000, 35000, 20000, 50000, 40000]}

# %%
df=pd.DataFrame(a)
df
# Out:
#        Name        Dept  Salary
# 0     Imran          HR   30000
# 1     Sagar       Sales   35000
# 2     Komal  BackOffice   20000
# 3  Prashant          DB   50000
# 4     Payal        Tele   40000

# %%
df["Working_hours"]=[8,7,7,5,9]
df
# Out:
#        Name        Dept  Salary  Working_hours
# 0     Imran          HR   30000              8
# 1     Sagar       Sales   35000              7
# 2     Komal  BackOffice   20000              7
# 3  Prashant          DB   50000              5
# 4     Payal        Tele   40000              9

# %%
#To covert dataframe of pandas into an array of numpy

# %%
df.to_numpy()
# Out:
# array([['Imran', 'HR', 30000, 8],
#        ['Sagar', 'Sales', 35000, 7],
#        ['Komal', 'BackOffice', 20000, 7],
#        ['Prashant', 'DB', 50000, 5],
#        ['Payal', 'Tele', 40000, 9]], dtype=object)

# %%
#To Transpose given dataframe(Rows to columns and columns to rows)
df.T
# Out:
#                    0      1           2         3      4
# Name           Imran  Sagar       Komal  Prashant  Payal
# Dept              HR  Sales  BackOffice        DB   Tele
# Salary         30000  35000       20000     50000  40000
# Working_hours      8      7           7         5      9

# %%
#Loc and iloc-To get elements of df also make changes
# loc["Index value,column value"]
# iloc["index values,column index value"]

# %%
df.loc[2,"Name"]="Firdous"
df
# Out:
#        Name        Dept  Salary  Working_hours
# 0     Imran          HR   30000              8
# 1     Sagar       Sales   35000              7
# 2   Firdous  BackOffice   20000              7
# 3  Prashant          DB   50000              5
# 4     Payal        Tele   40000              9

# %%
df.loc[2:4,["Name","Salary"]]
# Out:
#        Name  Salary
# 2   Firdous   20000
# 3  Prashant   50000
# 4     Payal   40000

# %%
df.iloc[4,2]
# Out:
# 40000

# %%
#To drop certain data in dataframe row wise
#df

# %%
#df=df.drop(2,axis=0)
#df

# %%
#df

# %%
#To drop or remove data from df column wise

# %%
#df.drop(["Salary"],axis=1)

# %%
#df.drop(["Dept"],axis=1)

# %%
df
# Out:
#        Name        Dept  Salary  Working_hours
# 0     Imran          HR   30000              8
# 1     Sagar       Sales   35000              7
# 2   Firdous  BackOffice   20000              7
# 3  Prashant          DB   50000              5
# 4     Payal        Tele   40000              9

# %%
#To reset index
#df.reset_index(drop=True,inplace=True)
#df

# %%
import numpy as np
#df["Dept"][2]=np.NaN
#df

# %%
#To check missing value in df we use isnull(),if output=True then value missing else false 
# df["Dept"].isnull()
# df["Dept"].notnull()

# %%
# df.isnull()
# df.notnull()#To check wheather value is present or not we use notnull(),output=True if value present

# %%
#df.isnull().sum()#To get number of missing values in each column

# %%
#df.dropna(inplace=True)#To remove missing value from original data
#df

# %%
df
# Out:
#        Name        Dept  Salary  Working_hours
# 0     Imran          HR   30000              8
# 1     Sagar       Sales   35000              7
# 2   Firdous  BackOffice   20000              7
# 3  Prashant          DB   50000              5
# 4     Payal        Tele   40000              9

# %%
df["Name"][1]="Imran"
df
# Out:
# C:\Users\IMRAN_PC\AppData\Local\Temp\ipykernel_6992\3581851610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"][1]="Imran"
#        Name        Dept  Salary  Working_hours
# 0     Imran          HR   30000              8
# 1     Imran       Sales   35000              7
# 2   Firdous  BackOffice   20000              7
# 3  Prashant          DB   50000              5
# 4     Payal        Tele   40000              9

# %%
df["Dept"][1]="HR"
df
# Out:
# C:\Users\IMRAN_PC\AppData\Local\Temp\ipykernel_6992\3635720258.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dept"][1]="HR"
#        Name        Dept  Salary  Working_hours
# 0     Imran          HR   30000              8
# 1     Imran          HR   35000              7
# 2   Firdous  BackOffice   20000              7
# 3  Prashant          DB   50000              5
# 4     Payal        Tele   40000              9

# %%
df["Name"].value_counts()#To count the occurance of the values in df
# Out:
# Imran       2
# Firdous     1
# Prashant    1
# Payal       1
# Name: Name, dtype: int64

# %%
df["Dept"].value_counts()
# Out:
# HR            2
# BackOffice    1
# DB            1
# Tele          1
# Name: Dept, dtype: int64

# %%
df["Working_hours"].value_counts()
# Out:
# 7    2
# 8    1
# 5    1
# 9    1
# Name: Working_hours, dtype: int64

# %%
#To find the row*columns shape of df
df.shape
# Out:
# (5, 4)

# %%
Cafe={
    "Items":["Pizza","Burger","Momos","Sandwich","Roll"],
    "Prize":[500,200,100,70,90]
}

# %%
data=pd.DataFrame(Cafe)
data
# Out:
#       Items  Prize
# 0     Pizza    500
# 1    Burger    200
# 2     Momos    100
# 3  Sandwich     70
# 4      Roll     90

# %%
data["Prize"][3]=np.NaN
data
# Out:
# C:\Users\IMRAN_PC\AppData\Local\Temp\ipykernel_6992\433764134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Prize"][3]=np.NaN
#       Items  Prize
# 0     Pizza  500.0
# 1    Burger  200.0
# 2     Momos  100.0
# 3  Sandwich    NaN
# 4      Roll   90.0

# %%
data.dropna(inplace=True)
data
# Out:
#     Items  Prize
# 0   Pizza  500.0
# 1  Burger  200.0
# 2   Momos  100.0
# 4    Roll   90.0

# %%
data["Reviews"]=[1,0,1,1]
data
# Out:
#     Items  Prize  Reviews
# 0   Pizza  500.0        1
# 1  Burger  200.0        0
# 2   Momos  100.0        1
# 4    Roll   90.0        1

# %%
data.reset_index(drop=True,inplace=True)
data
# Out:
#     Items  Prize  Reviews
# 0   Pizza  500.0        1
# 1  Burger  200.0        0
# 2   Momos  100.0        1
# 3    Roll   90.0        1
